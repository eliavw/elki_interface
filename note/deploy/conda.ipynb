# %% [markdown]
# # Conda Environments
#
# This notebook automatically configures a conda environment. This notebook is typically what you run before anything else in the project. In that way, you are set up with a controlled and isolated environment for further development/research.

# %% [markdown]
# ## Imports

# %%
import os
from os.path import dirname

# %% [markdown]
# ## Initialization
#
# Some important variables to be used afterwards.

# %%
name = "elki_interface"

root_dir = dirname(dirname(os.getcwd()))

fn_conda_dep = 'dependencies-deploy.yaml'
fn_conda_dev = 'dependencies-develop.yaml'

# %% [markdown]
# # Introduction
#
# This cookiecutter is set up for optimal use with conda, for local dependency managment. The takeaway is this; for local dependency managment, we rely on conda and nothing else.
#
# Note that this has nothing to do with remote dependency managment. This is what you need to take care of when preparing a release of your code which goes via PyPi or alternatives. We treat that as an independent problem. Mixing remote and local dependency managment tends to add complexity instead of removing it.

# %% [markdown]
# # Workflow
#
# We distinguish between `deployment` and `development` environments. Of course, in research this is not always that useful or clear. We follow this rule of thumb:
#
# ```
# Everything that should end up in pip release, goes in deployment
# ```
#
# Which still justifies keeping the two separated.

# %% [markdown]
# ## Deployment Environment
#
# This environment is whatever an end user may need in order to use your package.

# %%
# %%bash -s "$name" "$root_dir" "$fn_conda_dep"
#
# source ~/.bashrc
#
# conda env list
# Out:
# # conda environments:
# #
# base                  *  /home/zissou/miniconda3
# DEDT                     /home/zissou/miniconda3/envs/DEDT
# admercs                  /home/zissou/miniconda3/envs/admercs
# db                       /home/zissou/miniconda3/envs/db
# diacom                   /home/zissou/miniconda3/envs/diacom
# invariant_dt             /home/zissou/miniconda3/envs/invariant_dt
# mercs                    /home/zissou/miniconda3/envs/mercs
# tunify                   /home/zissou/miniconda3/envs/tunify

# %%
# %%bash -s "$name" "$root_dir" "$fn_conda_dep"
#
# source ~/.bashrc
#
# cd $2
#
# conda env create -f $3 -n $1
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# openssl-1.1.1k       | 2.5 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['/home/zissou/miniconda3/envs/elki_interface/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/zissou/repos/elki_interface/condaenv.pi4hrtw9.requirements.txt']
# Pip subprocess output:
# Collecting numpy
#   Downloading numpy-1.20.2-cp39-cp39-manylinux2010_x86_64.whl (15.4 MB)
# Collecting scipy
#   Downloading scipy-1.6.2-cp39-cp39-manylinux1_x86_64.whl (27.3 MB)
# Collecting pandas
#   Downloading pandas-1.2.3-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
# Collecting ipython
#   Downloading ipython-7.22.0-py3-none-any.whl (785 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp39-cp39-manylinux1_x86_64.whl (10.3 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.1-cp39-cp39-manylinux2010_x86_64.whl (23.8 MB)
# Collecting prefect
#   Downloading prefect-0.14.14-py3-none-any.whl (501 kB)
# Requirement already satisfied: setuptools>=18.5 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython->-r /home/zissou/repos/elki_interface/condaenv.pi4hrtw9.requirements.txt (line 4)) (52.0.0.post20210125)
# Collecting pexpect>4.3
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting pygments
#   Downloading Pygments-2.8.1-py3-none-any.whl (983 kB)
# Collecting backcall
#   Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting jedi>=0.16
#   Using cached jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
# Collecting traitlets>=4.2
#   Using cached traitlets-5.0.5-py3-none-any.whl (100 kB)
# Collecting decorator
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.18-py3-none-any.whl (367 kB)
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
# Collecting ptyprocess>=0.5
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Using cached wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.1.2-cp39-cp39-manylinux1_x86_64.whl (2.2 MB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp39-cp39-manylinux1_x86_64.whl (1.2 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting six
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting pytz>=2017.3
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting python-slugify>=1.2.6
#   Using cached python_slugify-4.0.1-py2.py3-none-any.whl
# Collecting click>=7.0
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting distributed>=2.17.0
#   Downloading distributed-2021.3.1-py3-none-any.whl (679 kB)
# Collecting marshmallow>=3.0.0b19
#   Downloading marshmallow-3.11.1-py2.py3-none-any.whl (46 kB)
# Collecting msgpack>=0.6.0
#   Using cached msgpack-1.0.2-cp39-cp39-manylinux1_x86_64.whl (294 kB)
# Collecting cloudpickle>=1.3.0
#   Using cached cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting pyyaml>=3.13
#   Using cached PyYAML-5.4.1-cp39-cp39-manylinux1_x86_64.whl (630 kB)
# Collecting requests>=2.20
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting dask>=2.17.0
#   Downloading dask-2021.3.1-py3-none-any.whl (935 kB)
# Collecting pendulum>=2.0.4
#   Using cached pendulum-2.1.2-cp39-cp39-manylinux1_x86_64.whl (155 kB)
# Collecting mypy-extensions>=0.4.0
#   Using cached mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting toml>=0.9.4
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting marshmallow-oneofschema>=2.0.0b2
#   Using cached marshmallow_oneofschema-2.1.0-py2.py3-none-any.whl (5.7 kB)
# Collecting urllib3>=1.24.3
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting tabulate>=0.8.0
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting python-box>=5.1.0
#   Using cached python_box-5.3.0-py3-none-any.whl (21 kB)
# Collecting docker>=3.4.1
#   Using cached docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting croniter<1.0,>=0.3.24
#   Using cached croniter-0.3.37-py2.py3-none-any.whl (13 kB)
# Collecting natsort
#   Using cached natsort-7.1.1-py3-none-any.whl (35 kB)
# Collecting partd>=0.3.10
#   Downloading partd-1.1.0-py3-none-any.whl (19 kB)
# Collecting toolz>=0.8.2
#   Using cached toolz-0.11.1-py3-none-any.whl (55 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-0.8.7-py3-none-any.whl (103 kB)
# Collecting tornado>=6.0.3
#   Using cached tornado-6.1-cp39-cp39-manylinux2010_x86_64.whl (427 kB)
# Collecting zict>=0.1.3
#   Using cached zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting tblib>=1.6.0
#   Using cached tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Using cached sortedcontainers-2.3.0-py2.py3-none-any.whl (29 kB)
# Collecting psutil>=5.0
#   Using cached psutil-5.8.0-cp39-cp39-manylinux2010_x86_64.whl (293 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pytzdata>=2020.1
#   Using cached pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
# Collecting text-unidecode>=1.3
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from requests>=2.20->prefect->-r /home/zissou/repos/elki_interface/condaenv.pi4hrtw9.requirements.txt (line 7)) (2020.12.5)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting heapdict
#   Using cached HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Installing collected packages: toolz, locket, urllib3, six, pyyaml, partd, idna, heapdict, fsspec, cloudpickle, chardet, zict, websocket-client, wcwidth, tornado, text-unidecode, tblib, sortedcontainers, requests, pytzdata, python-dateutil, ptyprocess, psutil, parso, numpy, natsort, msgpack, marshmallow, ipython-genutils, dask, click, traitlets, toml, threadpoolctl, tabulate, scipy, pytz, python-slugify, python-box, pyparsing, pygments, prompt-toolkit, pillow, pickleshare, pexpect, pendulum, mypy-extensions, marshmallow-oneofschema, kiwisolver, joblib, jedi, docker, distributed, decorator, cycler, croniter, backcall, scikit-learn, prefect, pandas, matplotlib, ipython
# Successfully installed backcall-0.2.0 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 croniter-0.3.37 cycler-0.10.0 dask-2021.3.1 decorator-4.4.2 distributed-2021.3.1 docker-4.4.4 fsspec-0.8.7 heapdict-1.0.1 idna-2.10 ipython-7.22.0 ipython-genutils-0.2.0 jedi-0.18.0 joblib-1.0.1 kiwisolver-1.3.1 locket-0.2.1 marshmallow-3.11.1 marshmallow-oneofschema-2.1.0 matplotlib-3.4.1 msgpack-1.0.2 mypy-extensions-0.4.3 natsort-7.1.1 numpy-1.20.2 pandas-1.2.3 parso-0.8.2 partd-1.1.0 pendulum-2.1.2 pexpect-4.8.0 pickleshare-0.7.5 pillow-8.1.2 prefect-0.14.14 prompt-toolkit-3.0.18 psutil-5.8.0 ptyprocess-0.7.0 pygments-2.8.1 pyparsing-2.4.7 python-box-5.3.0 python-dateutil-2.8.1 python-slugify-4.0.1 pytz-2021.1 pytzdata-2020.1 pyyaml-5.4.1 requests-2.25.1 scikit-learn-0.24.1 scipy-1.6.2 six-1.15.0 sortedcontainers-2.3.0 tabulate-0.8.9 tblib-1.7.0 text-unidecode-1.3 threadpoolctl-2.1.0 toml-0.10.2 toolz-0.11.1 tornado-6.1 traitlets-5.0.5 urllib3-1.26.4 wcwidth-0.2.5 websocket-client-0.58.0 zict-2.0.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate elki_interface
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# ### Installation of `AFFE`
#
# At some point, this will become better.

# %%
# %%bash -s "$name" "$root_dir"
#
# source ~/.bashrc
#
# cd $2
#
# conda activate $1
#
# pip install git+https://github.com/eliavw/affe.git
# Out:
# Collecting git+https://github.com/eliavw/affe.git
#   Cloning https://github.com/eliavw/affe.git to /tmp/pip-req-build-507u8jnk
# Requirement already satisfied: numpy in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from affe==0.0.0) (1.20.2)
# Requirement already satisfied: scipy in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from affe==0.0.0) (1.6.2)
# Requirement already satisfied: pandas in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from affe==0.0.0) (1.2.3)
# Collecting lxml
#   Downloading lxml-4.6.3-cp39-cp39-manylinux1_x86_64.whl (5.4 MB)
# Requirement already satisfied: requests in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from affe==0.0.0) (2.25.1)
# Requirement already satisfied: psutil in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from affe==0.0.0) (5.8.0)
# Collecting dill
#   Using cached dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting tqdm
#   Downloading tqdm-4.59.0-py2.py3-none-any.whl (74 kB)
# Requirement already satisfied: dask[distributed] in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from affe==0.0.0) (2021.3.1)
# Requirement already satisfied: fsspec>=0.6.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from dask[distributed]->affe==0.0.0) (0.8.7)
# Requirement already satisfied: toolz>=0.8.2 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from dask[distributed]->affe==0.0.0) (0.11.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from dask[distributed]->affe==0.0.0) (1.6.0)
# Requirement already satisfied: pyyaml in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from dask[distributed]->affe==0.0.0) (5.4.1)
# Requirement already satisfied: partd>=0.3.10 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from dask[distributed]->affe==0.0.0) (1.1.0)
# Requirement already satisfied: distributed>=2021.03.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from dask[distributed]->affe==0.0.0) (2021.3.1)
# Requirement already satisfied: tornado>=6.0.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (6.1)
# Requirement already satisfied: setuptools in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (52.0.0.post20210125)
# Requirement already satisfied: zict>=0.1.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (2.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (1.0.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (2.3.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (1.7.0)
# Requirement already satisfied: click>=6.6 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (7.1.2)
# Requirement already satisfied: locket in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from partd>=0.3.10->dask[distributed]->affe==0.0.0) (0.2.1)
# Requirement already satisfied: heapdict in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from zict>=0.1.3->distributed>=2021.03.0->dask[distributed]->affe==0.0.0) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from pandas->affe==0.0.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from pandas->affe==0.0.0) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->affe==0.0.0) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from requests->affe==0.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from requests->affe==0.0.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from requests->affe==0.0.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from requests->affe==0.0.0) (1.26.4)
# Building wheels for collected packages: affe
#   Building wheel for affe (setup.py): started
#   Building wheel for affe (setup.py): finished with status 'done'
#   Created wheel for affe: filename=affe-0.0.0-py2.py3-none-any.whl size=48110 sha256=dc8ab7dff22e339567e0127de22f68893a86716da03d963049f2fc4943ee2598
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0vf_m5s3/wheels/40/79/92/dc97bce20dd691decadabef1b6db460cd9d215164d78ba6616
# Successfully built affe
# Installing collected packages: tqdm, lxml, dill, affe
# Successfully installed affe-0.0.0 dill-0.3.3 lxml-4.6.3 tqdm-4.59.0
#   Running command git clone -q https://github.com/eliavw/affe.git /tmp/pip-req-build-507u8jnk

# %% [markdown]
# ## Development environment

# %%
# %%bash -s "$name" "$root_dir" "$fn_conda_dev"
#
# source ~/.bashrc
#
# cd $2
#
# conda activate $1
#
# conda env update -n $1 -f $3
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# markdown-3.3.4       | 129 KB    | ########## | 100%
# urllib3-1.26.4       | 105 KB    | ########## | 100%
# terminado-0.9.3      | 25 KB     | ########## | 100%
# jupyter_client-6.1.1 | 88 KB     | ########## | 100%
# defusedxml-0.7.1     | 23 KB     | ########## | 100%
# importlib-metadata-3 | 31 KB     | ########## | 100%
# cryptography-3.4.7   | 906 KB    | ########## | 100%
# mkdocs-material-exte | 11 KB     | ########## | 100%
# pandoc-2.12          | 9.5 MB    | ########## | 100%
# tqdm-4.59.0          | 93 KB     | ########## | 100%
# anyio-2.2.0          | 122 KB    | ########## | 100%
# importlib_metadata-3 | 11 KB     | ########## | 100%
# jupyterlab-3.0.11    | 3.5 MB    | ########## | 100%
# zipp-3.4.1           | 15 KB     | ########## | 100%
# mkdocs-material-7.1. | 1.9 MB    | ########## | 100%
# nbclassic-0.2.6      | 19 KB     | ########## | 100%
# sniffio-1.2.0        | 15 KB     | ########## | 100%
# regex-2021.3.17      | 318 KB    | ########## | 100%
# toml-0.10.2          | 20 KB     | ########## | 100%
# jupyterlab_server-2. | 37 KB     | ########## | 100%
# jupyter-packaging-0. | 14 KB     | ########## | 100%
# notebook-6.3.0       | 4.1 MB    | ########## | 100%
# pluggy-0.13.1        | 33 KB     | ########## | 100%
# jupyter_server-1.4.1 | 313 KB    | ########## | 100%
# nbclient-0.5.3       | 62 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['/home/zissou/miniconda3/envs/elki_interface/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt']
# Pip subprocess output:
# Collecting semantic-version
#   Using cached semantic_version-2.8.5-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: ipykernel in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from -r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (5.3.4)
# Collecting ipykernel
#   Downloading ipykernel-5.5.3-py3-none-any.whl (120 kB)
# Collecting mkdocs-minify-plugin
#   Using cached mkdocs_minify_plugin-0.4.0-py3-none-any.whl
# Requirement already satisfied: pymdown-extensions in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from -r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 4)) (8.1.1)
# Collecting nb-black
#   Using cached nb_black-1.0.7-py3-none-any.whl
# Requirement already satisfied: tornado>=4.2 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (6.1)
# Requirement already satisfied: jupyter-client in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (7.22.0)
# Requirement already satisfied: traitlets>=4.1.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (5.0.5)
# Requirement already satisfied: backcall in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: decorator in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: pygments in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (52.0.0.post20210125)
# Requirement already satisfied: pexpect>4.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (3.0.18)
# Requirement already satisfied: pickleshare in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: ipython-genutils in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from traitlets>=4.1.0->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (0.2.0)
# Collecting htmlmin>=0.1.4
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied: mkdocs>=1.0.4 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (1.1.2)
# Collecting jsmin>=2.2.2
#   Using cached jsmin-2.2.2-py3-none-any.whl
# Requirement already satisfied: Markdown>=3.2.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (3.3.4)
# Requirement already satisfied: click>=3.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: livereload>=2.5.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (2.6.3)
# Requirement already satisfied: lunr[languages]==0.5.8 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (0.5.8)
# Requirement already satisfied: PyYAML>=3.10 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (5.4.1)
# Requirement already satisfied: six>=1.11.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from lunr[languages]==0.5.8->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: future>=0.16.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from lunr[languages]==0.5.8->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (0.18.2)
# Requirement already satisfied: nltk>=3.2.5 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from lunr[languages]==0.5.8->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (3.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from Jinja2>=2.10.1->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: tqdm in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from nltk>=3.2.5->lunr[languages]==0.5.8->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (4.59.0)
# Requirement already satisfied: joblib in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from nltk>=3.2.5->lunr[languages]==0.5.8->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: regex in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from nltk>=3.2.5->lunr[languages]==0.5.8->mkdocs>=1.0.4->mkdocs-minify-plugin->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 3)) (2021.3.17)
# Collecting black>='19.3'
#   Using cached black-20.8b1-py3-none-any.whl
# Collecting pathspec<1,>=0.6
#   Using cached pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: toml>=0.10.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from black>='19.3'->nb-black->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 5)) (0.10.2)
# Collecting typed-ast>=1.4.0
#   Using cached typed_ast-1.4.2-cp39-cp39-manylinux1_x86_64.whl (769 kB)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from black>='19.3'->nb-black->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 5)) (0.4.3)
# Collecting typing-extensions>=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting appdirs
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from jupyter-client->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from jupyter-client->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages (from jupyter-client->ipykernel->-r /home/zissou/repos/elki_interface/condaenv.bmtyew00.requirements.txt (line 2)) (4.7.1)
# Installing collected packages: typing-extensions, typed-ast, pathspec, appdirs, jsmin, htmlmin, black, semantic-version, nb-black, mkdocs-minify-plugin, ipykernel
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.4
#     Uninstalling ipykernel-5.3.4:
#       Successfully uninstalled ipykernel-5.3.4
# Successfully installed appdirs-1.4.4 black-20.8b1 htmlmin-0.1.12 ipykernel-5.5.3 jsmin-2.2.2 mkdocs-minify-plugin-0.4.0 nb-black-1.0.7 pathspec-0.8.1 semantic-version-2.8.5 typed-ast-1.4.2 typing-extensions-3.7.4.3
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate elki_interface
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# ### Install elki_interface
#
# Installing the source code of this repo as a package itself. This is often quite useful.

# %%
# %%bash -s "$name" "$root_dir" "$fn_conda_dev"
#
# source ~/.bashrc
#
# cd $2
#
# conda activate $1
#
# python setup.py develop
# Out:
# running develop
# running egg_info
# creating src/elki_interface.egg-info
# writing src/elki_interface.egg-info/PKG-INFO
# writing dependency_links to src/elki_interface.egg-info/dependency_links.txt
# writing requirements to src/elki_interface.egg-info/requires.txt
# writing top-level names to src/elki_interface.egg-info/top_level.txt
# writing manifest file 'src/elki_interface.egg-info/SOURCES.txt'
# reading manifest file 'src/elki_interface.egg-info/SOURCES.txt'
# writing manifest file 'src/elki_interface.egg-info/SOURCES.txt'
# running build_ext
# Creating /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages/elki-interface.egg-link (link to src)
# Adding elki-interface 0.0.8 to easy-install.pth file
#
# Installed /home/zissou/repos/elki_interface/src
# Processing dependencies for elki-interface==0.0.8
# Searching for prefect==0.14.14
# Best match: prefect 0.14.14
# Adding prefect 0.14.14 to easy-install.pth file
# Installing prefect script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for pandas==1.2.3
# Best match: pandas 1.2.3
# Adding pandas 1.2.3 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for scipy==1.6.2
# Best match: scipy 1.6.2
# Adding scipy 1.6.2 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for numpy==1.20.2
# Best match: numpy 1.20.2
# Adding numpy 1.20.2 to easy-install.pth file
# Installing f2py script to /home/zissou/miniconda3/envs/elki_interface/bin
# Installing f2py3 script to /home/zissou/miniconda3/envs/elki_interface/bin
# Installing f2py3.9 script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for pendulum==2.1.2
# Best match: pendulum 2.1.2
# Adding pendulum 2.1.2 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for requests==2.25.1
# Best match: requests 2.25.1
# Adding requests 2.25.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for click==7.1.2
# Best match: click 7.1.2
# Adding click 7.1.2 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for python-slugify==4.0.1
# Best match: python-slugify 4.0.1
# Adding python-slugify 4.0.1 to easy-install.pth file
# Installing slugify script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for croniter==0.3.37
# Best match: croniter 0.3.37
# Adding croniter 0.3.37 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for python-box==5.3.0
# Best match: python-box 5.3.0
# Adding python-box 5.3.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for python-dateutil==2.8.1
# Best match: python-dateutil 2.8.1
# Adding python-dateutil 2.8.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for msgpack==1.0.2
# Best match: msgpack 1.0.2
# Adding msgpack 1.0.2 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for dask==2021.3.1
# Best match: dask 2021.3.1
# Adding dask 2021.3.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for PyYAML==5.4.1
# Best match: PyYAML 5.4.1
# Adding PyYAML 5.4.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for urllib3==1.26.4
# Best match: urllib3 1.26.4
# Adding urllib3 1.26.4 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for pytz==2021.1
# Best match: pytz 2021.1
# Adding pytz 2021.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for tabulate==0.8.9
# Best match: tabulate 0.8.9
# Adding tabulate 0.8.9 to easy-install.pth file
# Installing tabulate script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for marshmallow-oneofschema==2.1.0
# Best match: marshmallow-oneofschema 2.1.0
# Adding marshmallow-oneofschema 2.1.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for docker==4.4.4
# Best match: docker 4.4.4
# Adding docker 4.4.4 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for marshmallow==3.11.1
# Best match: marshmallow 3.11.1
# Adding marshmallow 3.11.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for distributed==2021.3.1
# Best match: distributed 2021.3.1
# Adding distributed 2021.3.1 to easy-install.pth file
# Installing dask-ssh script to /home/zissou/miniconda3/envs/elki_interface/bin
# Installing dask-scheduler script to /home/zissou/miniconda3/envs/elki_interface/bin
# Installing dask-worker script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for toml==0.10.2
# Best match: toml 0.10.2
# Adding toml 0.10.2 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for cloudpickle==1.6.0
# Best match: cloudpickle 1.6.0
# Adding cloudpickle 1.6.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for mypy-extensions==0.4.3
# Best match: mypy-extensions 0.4.3
# Adding mypy-extensions 0.4.3 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for pytzdata==2020.1
# Best match: pytzdata 2020.1
# Adding pytzdata 2020.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for certifi==2020.12.5
# Best match: certifi 2020.12.5
# Adding certifi 2020.12.5 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for chardet==4.0.0
# Best match: chardet 4.0.0
# Adding chardet 4.0.0 to easy-install.pth file
# Installing chardetect script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for text-unidecode==1.3
# Best match: text-unidecode 1.3
# Adding text-unidecode 1.3 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for natsort==7.1.1
# Best match: natsort 7.1.1
# Adding natsort 7.1.1 to easy-install.pth file
# Installing natsort script to /home/zissou/miniconda3/envs/elki_interface/bin
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for toolz==0.11.1
# Best match: toolz 0.11.1
# Adding toolz 0.11.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for fsspec==0.8.7
# Best match: fsspec 0.8.7
# Adding fsspec 0.8.7 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for partd==1.1.0
# Best match: partd 1.1.0
# Adding partd 1.1.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for websocket-client==0.58.0
# Best match: websocket-client 0.58.0
# Adding websocket-client 0.58.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for psutil==5.8.0
# Best match: psutil 5.8.0
# Adding psutil 5.8.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for tblib==1.7.0
# Best match: tblib 1.7.0
# Adding tblib 1.7.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for setuptools==52.0.0.post20210125
# Best match: setuptools 52.0.0.post20210125
# Adding setuptools 52.0.0.post20210125 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for sortedcontainers==2.3.0
# Best match: sortedcontainers 2.3.0
# Adding sortedcontainers 2.3.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for zict==2.0.0
# Best match: zict 2.0.0
# Adding zict 2.0.0 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for tornado==6.1
# Best match: tornado 6.1
# Adding tornado 6.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for locket==0.2.1
# Best match: locket 0.2.1
# Adding locket 0.2.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Searching for HeapDict==1.0.1
# Best match: HeapDict 1.0.1
# Adding HeapDict 1.0.1 to easy-install.pth file
#
# Using /home/zissou/miniconda3/envs/elki_interface/lib/python3.9/site-packages
# Finished processing dependencies for elki-interface==0.0.8

# %% [markdown]
# ## Jupyter kernel
#
# Expose the environment to your jupyter.

# %%
# %%bash -s "$name" "$root_dir" "$fn_conda_dep"
#
# source ~/.bashrc
#
# cd $2
#
# conda activate $1
# python -m ipykernel install --user --name $1
# Out:
# Installed kernelspec elki_interface in /home/zissou/.local/share/jupyter/kernels/elki_interface
